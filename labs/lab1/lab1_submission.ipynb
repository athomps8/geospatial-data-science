# %%
import numpy as np
x = 6
y = 13
z = np.multiply(x, y)
print(z)
# Out:
# 78

# %% [markdown]
# ![northernlights.jpg](attachment:northernlights.jpg)
#
# **Northern Lights in the night sky**
# *This image shows the northern lights which are an interaction between Earth's magnetic field and charged particles emitted by the sun*
#
# URL: https://www.gannett-cdn.com/presto/2018/12/15/USAT/2e7b9863-85ac-4faa-aad3-096fc1826c20-GettyImages-841647034.jpg
